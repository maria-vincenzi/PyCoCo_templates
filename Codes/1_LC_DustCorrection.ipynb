# %% [markdown]
# # Correct Photometry for dust extinction

# %% [markdown]
# Correct broad-band photometry for Host and MW extinction (if this has not been already done.. 99% of the time the photometry is published before dust corrections).
#
# Assumptions: R_V always equal 3.1

# %%
import os
COCO_PATH=os.environ['COCO_PATH']

# %%
import numpy as np
import pandas as pd

# %%
DATALC_PATH = "/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW/"
DATAMAIN_PATH= "/Users/mariavincenzi/PhD/pycoco_2/data/"

CSP_SNe = ['SN2004fe', 'SN2005bf', 'SN2006V', 'SN2007C', 'SN2007Y',
           'SN2009bb',  'SN2008aq', 'SN2006T', 'SN2004gq', 'SN2004gt',
           'SN2004gv','SN2006ep', 'SN2008fq', 'SN2006aa']

Vega_filt = ['Bessell_U', 'Bessell_B','Bessell_V','Bessell_R','Bessell_I', 
            'swift_UVW2', 'swift_UVM2', 'swift_UVW1', 'swift_U', 'swift_B','swift_V',
            'Y', 'H', 'J', 'K', 'Ks']
AB_filt = ['sdss_u', 'sdss_g','sdss_r','sdss_i','sdss_z', 
            "sdss_u'", "sdss_g'", "sdss_r'", "sdss_i'", "sdss_z'"]

exclude_filt = ['H', 'J', 'K', 'Ks','KS', 'Y']
info_objects = pd.read_csv(DATAMAIN_PATH+'info/FINAL_info.dat')

# %%
info_objects
# Out:
#           Name  TMPL_INDEX   Type Rich_Type        z  MW ebv    Host ebv  \
# 0   ASASSN14jb         1.0     II       IIP  0.00603   0.019           0
# 1   ASASSN15oz         2.0     II       IIL  0.00693   0.092           0
# 2      SN1987A        67.0     II       IIP  0.00001   0.000        0.17
# 3      SN1993J         4.0    IIb       IIb -0.00010   0.080         0.1
# 4      SN1994I         5.0     Ic        Ic  0.00150   0.035        0.42
# 5     SN1998bw         6.0  Ic-BL     Ic-BL  0.00850   0.059           0
# 6     SN1999dn         7.0     Ib        Ib  0.00930   0.052       0.048
# 7     SN1999em         8.0     II       IIP  0.00239   0.041       0.077
# 8     SN2002ap         9.0  Ic-BL     Ic-BL  0.00220   0.072       0.008
# 9     SN2004aw        10.0     Ic        Ic  0.01590   0.021        0.35
# 10    SN2004et        11.0     II       IIP  0.00105   0.342        0.07
# 11    SN2004fe        12.0     Ic        Ic  0.01800   0.024           0
# 12    SN2004gq        13.0     Ib        Ib  0.00647   0.073       0.067
# 13    SN2004gt        14.0     Ic        Ic  0.00548   0.046       0.237
# 14    SN2004gv        15.0     Ib        Ib  0.02000   0.033       0.053
# 15    SN2005bf        16.0     Ib        Ib  0.01890   0.045         0.1
# 16    SN2005cs        17.0     II       IIP  0.00154   0.036       0.015
# 17    SN2005hg        18.0     Ib        Ib  0.02100   0.105  0.2235ddag
# 18     SN2006T        22.0    IIb       IIb  0.00810   0.075       0.277
# 19    SN2006aa        19.0    IIn       IIn  0.02070   0.041   0.081ddag
# 20    SN2006aj        20.0  Ic-BL     Ic-BL  0.03340   0.145         0.2
# 21    SN2006ep        21.0     Ib        Ib  0.01500   0.036       0.233
# 22     SN2007Y        28.0     Ib        Ib  0.00460   0.022        0.09
# 23    SN2007gr        23.0     Ic        Ic  0.00170   0.062        0.03
# 24    SN2007od        24.0     II       IIL  0.00586   0.037           0
# 25    SN2007pk        25.0    IIn       IIn  0.01665   0.052   0.081ddag
# 26    SN2007ru        26.0  Ic-BL     Ic-BL  0.01550   0.261           0
# 27    SN2007uy        27.0     Ib        Ib  0.00700   0.023        0.63
# 28     SN2008D        33.0     Ib        Ib  0.00700   0.023         0.6
# 29    SN2008aq        29.0    IIb       IIb  0.00797   0.045           0
# ..         ...         ...    ...       ...      ...     ...         ...
# 37    SN2009bw        37.0     II       IIP  0.00382   0.229        0.08
# 38    SN2009dd        38.0     II       IIL  0.00246   0.020       0.433
# 39    SN2009ib        39.0     II       IIP  0.00435   0.030       0.131
# 40    SN2009ip        40.0    IIn       IIn  0.00594   0.020        0.01
# 41    SN2009iz        41.0     Ib        Ib  0.01420   0.085  0.2235ddag
# 42    SN2009jf        42.0     Ib        Ib  0.00800   0.113        0.03
# 43    SN2009kr        43.0     II       IIL  0.00650   0.073           0
# 44    SN2010al        45.0    IIn       IIn  0.01700   0.047       0.053
# 45    SN2011bm        46.0     Ic        Ic  0.00220   0.034       0.032
# 46    SN2011dh        47.0    IIb       IIb  0.00150   0.036        0.05
# 47    SN2011ei        48.0    IIb       IIb  0.00930   0.059        0.18
# 48    SN2011fu        49.0    IIb       IIb  0.01850   0.077       0.015
# 49    SN2011hs        50.0    IIb       IIb  0.00571   0.012        0.16
# 50    SN2011ht        51.0    IIn       IIn  0.00360   0.011       0.061
# 51     SN2012A        52.0     II       IIP  0.00231   0.032       0.012
# 52    SN2012ap        53.0  Ic-BL     Ic-BL  0.01210   0.051         0.4
# 53    SN2012au        54.0     Ib        Ib  0.00450   0.000           0
# 54    SN2012aw        55.0     II       IIP  0.00260   0.028       0.028
# 55    SN2013ab        56.0     II       IIP  0.00532   0.027        0.02
# 56    SN2013am        57.0     II       IIP  0.00269   0.025        0.55
# 57    SN2013by        58.0     II       IIL  0.00359   0.220           0
# 58    SN2013df        59.0    IIb       IIb  0.00239   0.019        0.08
# 59    SN2013ej        60.0     II       IIL  0.00219   0.070       0.049
# 60    SN2013fs        61.0     II       IIP  0.01185   0.040       0.015
# 61    SN2013ge        62.0     Ic        Ic  0.00550   0.023       0.047
# 62     SN2014G        63.0     II       IIL  0.00563   0.012        0.24
# 63     SN2016X        66.0     II       IIP  0.00441   0.022        0.02
# 64   SN2016bkv        64.0     II       IIP  0.00200   0.017           0
# 65   SN2016gkg        65.0    IIb       IIb  0.00492   0.019        0.09
# 66   iPTF13bvn         3.0     Ib        Ib  0.00449   0.051        0.17
#
#     mjd Lbol peak    M_B        M_V  ...   M_R_wHost  logL_BVRI  \
# 0         56955.2 -16.11 -16.155973  ...  -16.599061   1.627262
# 1         57267.4 -18.19 -18.166629  ...  -18.413867   2.431693
# 2         46928.0 -14.33 -15.736188  ...  -15.881565   1.434645
# 3         49076.0 -13.22 -13.035326  ...  -12.843627   0.361242
# 4         49451.0 -17.05 -17.516303  ...  -16.422076   2.061696
# 5         50944.0 -18.93 -19.382352  ...  -19.324625   2.809612
# 6         51421.0 -16.62 -17.217121  ...  -17.263053   1.971038
# 7         51483.1 -16.69 -16.609937  ...  -16.605568   1.807691
# 8         52313.1 -17.07 -17.737450  ...  -17.768605   2.136584
# 9         53090.0 -17.66 -18.079022  ...  -17.333754   2.321504
# 10        53284.5 -17.09 -17.009018  ...  -16.971529   1.966677
# 11        53318.2 -17.05 -17.475537  ...  -17.682667   2.088358
# 12        53359.3 -16.97 -17.296753  ...  -17.383683   2.064533
# 13        53361.8 -16.66 -17.414373  ...  -17.103971   2.080027
# 14        53366.6 -17.39 -17.740404  ...  -17.852408   2.213186
# 15        53500.2 -18.44 -18.602734  ...  -18.472123   2.572267
# 16        53553.5 -14.90 -14.742243  ...  -15.069075   1.074553
# 17        53683.0 -18.02 -18.243814  ...  -17.835958   2.426412
# 18        53781.3 -17.72 -18.151577  ...  -17.554265   2.348677
# 19        53818.0 -17.61 -17.681388  ...  -17.626878   2.229908
# 20        53784.6 -19.33 -19.338988  ...  -19.354497   3.041327
# 21        53988.3 -17.16 -17.540351  ...  -17.129647   2.134169
# 22        54165.3 -16.32 -16.505921  ...  -16.399950   1.727210
# 23        54338.0 -16.20 -16.668671  ...  -16.713862   1.755567
# 24        54408.0 -17.93 -17.957909  ...  -18.118476   2.347393
# 25        54423.6 -18.71 -18.610628  ...  -18.543464   2.613699
# 26        54438.5 -18.65 -18.985965  ...  -19.060079   2.697036
# 27        54480.0 -18.34 -18.674665  ...  -17.062243   2.537011
# 28        54494.0 -16.47 -17.002011  ...  -15.754217   1.938522
# 29        54532.1 -16.60 -17.047974  ...  -17.576147   1.982792
# ..            ...    ...        ...  ...         ...        ...
# 37        54923.9 -17.14 -17.101686  ...  -16.993367   2.004135
# 38        54936.0 -16.81 -16.737536  ...  -15.701194   1.823301
# 39        55056.3 -15.86 -15.990241  ...  -15.858806   1.547152
# 40        56205.5 -18.33 -18.331242  ...  -18.366982   2.484071
# 41        55107.6 -17.69 -17.905423  ...  -17.487175   2.287772
# 42        55121.2 -17.68 -18.088144  ...  -18.134819   2.339957
# 43        55150.6 -16.57 -16.843381  ...  -17.189048   1.909002
# 44        55282.0 -18.75 -18.741881  ...  -18.678202   2.649632
# 45        55677.1 -13.10 -13.553234  ...  -13.800454   0.547376
# 46        55734.6 -15.99 -16.726657  ...  -16.854041   1.777870
# 47        55785.0 -16.60 -16.756599  ...  -16.348905   1.820078
# 48        55828.0 -18.62 -18.712747  ...  -18.404507   2.572824
# 49        55888.0 -15.71 -16.680938  ...  -16.701249   1.779654
# 50        55881.0 -16.98 -16.906600  ...  -16.821235   1.926593
# 51        55944.0 -16.10 -16.153921  ...  -16.321232   1.614608
# 52        55978.0 -17.66 -18.329763  ...  -17.560443   2.411278
# 53        56007.0 -17.39 -18.051323  ...  -18.244586   2.312343
# 54        56012.0 -17.05 -17.096759  ...  -17.236372   1.996716
# 55        56347.2 -17.14 -17.221291  ...  -17.277350   2.032629
# 56        56381.2 -15.80 -15.775315  ...  -14.735769   1.477111
# 57        56414.0 -18.36 -18.386469  ...  -18.509754   2.512109
# 58        56451.9 -15.90 -16.129484  ...  -16.365621   1.665258
# 59        56509.4 -17.76 -17.737504  ...  -17.764670   2.242145
# 60        56577.8 -17.73 -17.773999  ...  -17.806205   2.251199
# 61        56619.3 -16.57 -17.216980  ...  -17.310757   1.984424
# 62        56682.4 -18.10 -18.223747  ...  -17.703916   2.419413
# 63        57416.6 -17.38 -17.406614  ...  -17.503613   2.119586
# 64        57475.3 -14.89 -14.908040  ...  -14.919602   1.098133
# 65        57672.3 -16.61 -16.972638  ...  -16.856113   1.890373
# 66        56477.0 -16.54 -16.859937  ...  -16.603978   1.854993
#
#          Band (Opt)             Band (UV) Spectra  \
# 0           $BVgri$    u,b,uvw1,uvm2,uvw2      10
# 1        $UBVRIgri$  u,b,v,uvw1,uvm2,uvw2      13
# 2           $UBVRI$                   NaN      18
# 3           $UBVRI$                   NaN      50
# 4           $UBVRI$                   NaN      27
# 5           $UBVRI$                   NaN      21
# 6           $UBVRI$                   NaN      13
# 7           $UBVRI$                   NaN      27
# 8           $UBVRI$                   NaN      23
# 9           $UBVRI$                   NaN      23
# 10          $UBVRI$                   NaN      28
# 11         $BVugri$                   NaN       9
# 12         $BVugri$                   NaN      24
# 13         $BVugri$                   NaN      13
# 14         $BVugri$                   NaN       5
# 15         $BVugri$                   NaN      26
# 16         $UBVRIz$      b,uvw1,uvm2,uvw2      18
# 17          $UBVri$                   NaN      20
# 18         $BVugri$                   NaN       6
# 19         $BVugri$                   NaN       6
# 20          $UBVri$  u,b,v,uvw1,uvm2,uvw2      22
# 21         $BVugri$                   NaN       7
# 22         $BVugri$  u,b,v,uvw1,uvm2,uvw2       6
# 23        $UBVRIri$                   NaN      36
# 24        $UBVRIri$  u,b,v,uvw1,uvm2,uvw2      13
# 25         $BVRIri$  u,b,v,uvw1,uvm2,uvw2       9
# 26          $UBVRI$                   NaN       5
# 27           $BVri$  u,b,v,uvw1,uvm2,uvw2      11
# 28           $BVri$            u,b,v,uvw1      20
# 29         $BVugri$       u,b,v,uvw1,uvw2       7
# ..              ...                   ...     ...
# 37          $UBVRI$             uvm2,uvw2      16
# 38        $UBVRIri$                   NaN       6
# 39      $BVRIugriz$                   NaN       9
# 40           $BVRI$      u,uvw1,uvm2,uvw2      55
# 41          $BVuri$                  uvw1      10
# 42  $UBVRIuugrriiz$                   NaN      31
# 43           $BVRI$  u,b,v,uvw1,uvm2,uvw2       6
# 44        $BVRIuri$  u,b,v,uvw1,uvm2,uvw2      11
# 45     $UBVRIugriz$                   NaN      13
# 46        $UBVRIgi$                   NaN      39
# 47           $BVRI$       u,b,v,uvw1,uvw2      11
# 48         $UBVRIz$                   NaN      28
# 49      $BVRIugriz$       u,b,v,uvw1,uvw2      13
# 50           $BVRI$  u,b,v,uvw1,uvm2,uvw2      12
# 51          $UBVRI$                   NaN      39
# 52           $BVRI$            u,b,v,uvw1      12
# 53          $BVRIz$  u,b,v,uvw1,uvm2,uvw2       5
# 54     $UBVRIugriz$  u,b,v,uvw1,uvm2,uvw2      30
# 55        $BVRIgri$    u,b,uvw1,uvm2,uvw2      22
# 56         $UBVRIi$    u,b,uvw1,uvm2,uvw2      14
# 57         $BVugri$    u,v,uvw1,uvm2,uvw2       7
# 58          $UBVRI$  u,b,v,uvw1,uvm2,uvw2      12
# 59      $UBVRIgriz$  u,b,v,uvw1,uvm2,uvw2      28
# 60          $BVRIr$      u,uvw1,uvm2,uvw2      23
# 61          $VRIri$  u,b,v,uvw1,uvm2,uvw2      18
# 62          $UBVRI$      v,uvw1,uvm2,uvw2      17
# 63       $UBVRIgri$  u,b,v,uvw1,uvm2,uvw2      33
# 64       $UBVRIgri$                   NaN      15
# 65         $BVRIgr$  u,b,v,uvw1,uvm2,uvw2      17
# 66      $UBVRIgriz$       u,b,v,uvw1,uvw2      25
#
#                                        Ref Photometry  \
# 0                                 2018arXiv181111771M
# 1                                 2019arXiv190109962A
# 2   1987MNRAS.229P..15C,1988MNRAS.231P..75C,1988MN...
# 3                                 1994AJ....107.1022R
# 4                                 1996AJ....111..327R
# 5                                 1998Natur.395..670G
# 6                                 2011MNRAS.411.2726B
# 7                                 2016AJ....151...33G
# 8             2002MNRAS.332L..73G,2003MNRAS.340..375P
# 9                             2006MNRAS.371.1459T,...
# 10                                2010MNRAS.404..981M
# 11                                2018A&A...609A.134S
# 12                                2018A&A...609A.134S
# 13                                2018A&A...609A.134S
# 14                                2018A&A...609A.134S
# 15                                2018A&A...609A.134S
# 16                                2009MNRAS.394.2266P
# 17                                2014ApJS..213...19B
# 18                                2018A&A...609A.134S
# 19                                2013A&A...555A..10T
# 20                                2014ApJS..213...19B
# 21                                2018A&A...609A.134S
# 22                                2018A&A...609A.134S
# 23            2014ApJS..213...19B,2014ApJ...790..120C
# 24                                2011MNRAS.417..261I
# 25            2017ApJS..233....6H,2013A&A...555A.142I
# 26                                2009ApJ...697..676S
# 27                                2014ApJS..213...19B
# 28            2014ApJS..213...19B,2008Sci...321.1185M
# 29                                2018A&A...609A.134S
# ..                                                ...
# 37                                2012MNRAS.422.1122I
# 38            2017ApJS..233....6H,2013A&A...555A.142I
# 39                                2015MNRAS.450.3137T
# 40            2015A&A...579A..40S,2013MNRAS.430.1801M
# 41                                2014ApJS..213...19B
# 42            2014ApJS..213...19B,2011MNRAS.416.3138V
# 43                                2010ApJ...714L.254E
# 44                                2017ApJS..233....6H
# 45                                2012ApJ...749L..28V
# 46  2013MNRAS.433....2S,2011ApJ...742L..18A,2012yC...
# 47                                2011CBET.2777....3M
# 48                                2015MNRAS.454...95M
# 49                                2014MNRAS.439.1807B
# 50            2013MNRAS.431.2599M,2012ApJ...751...92R
# 51                                2013MNRAS.434.1636T
# 52                                2015ApJ...799...51M
# 53  2013ApJ...772L..17T,2013ApJ...770L..38M,2013Ap...
# 54  2016ApJ...820...33R,2014ApJ...787..139D,2013Ne...
# 55                                2015MNRAS.450.2373B
# 56                                2014ApJ...797....5Z
# 57                                2015MNRAS.448.2608V
# 58                                2014MNRAS.445.1647M
# 59                                2016MNRAS.461.2003Y
# 60  2016MNRAS.459.3939V,2016ApJ...820...33R,2018MN...
# 61                                2016ApJ...821...57D
# 62                                2016MNRAS.455.2712B
# 63                                2018MNRAS.475.3959H
# 64            2018ApJ...861...63H,2018ApJ...859...78N
# 65                                2017ApJ...836L..12T
# 66            2016A&A...593A..68F,2014MNRAS.445.1932S
#
#                                      Ref Spectroscopy  \
# 0                                 2018arXiv181111771M
# 1                                 2019arXiv190109962A
# 2                                 1995ApJS...99..223P
# 3   1995A&AS..110..513B,2000AJ....120.1487M,2000AJ...
# 4   1995ApJ...450L..11F,1996ApJ...462..462C,2014AJ...
# 5                                 2001ApJ...555..900P
# 6                                 2011MNRAS.411.2726B
# 7             2001ApJ...558..615H,2002PASP..114...35L
# 8   2002MNRAS.332L..73G,2003PASP..115.1220F,2013Ap...
# 9                                 2006MNRAS.371.1459T
# 10  2006MNRAS.372.1315S,2014MNRAS.442..844F,2010MN...
# 11            2008A&A...488..383H,2014AJ....147...99M
# 12            2014AJ....147...99M,2017PASP..129e4201S
# 13  2008ApJ...687L...9M,2009MNRAS.397..677T,2014AJ...
# 14            2014AJ....147...99M,2019MNRAS.482.1545S
# 15  2006ApJ...641.1039F,2014AJ....147...99M,2019MN...
# 16  2006MNRAS.370.1752P,2009ApJ...700.1456B,2009MN...
# 17            2014AJ....147...99M,2019MNRAS.482.1545S
# 18            2014AJ....147...99M,2017PASP..129e4201S
# 19                                2013A&A...555A..10T
# 20  2006ApJ...645L..21M,2006Natur.442.1011P,2008As...
# 21            2014AJ....147...99M,2019MNRAS.482.1545S
# 22            2009ApJ...696..713S,2019MNRAS.482.1545S
# 23  2008ApJ...673L.155V,2019MNRAS.482.1545S,2014AJ...
# 24                                2011MNRAS.417..261I
# 25                                2013A&A...555A.142I
# 26            2014AJ....147...99M,2019MNRAS.482.1545S
# 27            2014AJ....147...99M,2019MNRAS.482.1545S
# 28  2009ApJ...702..226M,2014AJ....147...99M,2019MN...
# 29                                2014AJ....147...99M
# ..                                                ...
# 37                                2012MNRAS.422.1122I
# 38                                2013A&A...555A.142I
# 39                                2015MNRAS.450.3137T
# 40  2013MNRAS.433.1312F,2014ApJ...780...21M,2014Ap...
# 41            2014AJ....147...99M,2019MNRAS.482.1545S
# 42  2011MNRAS.416.3138V,2014AJ....147...99M,2019MN...
# 43                                2010ApJ...714L.254E
# 44  2015MNRAS.449.1921P,2016MNRAS.461.3057S,2019MN...
# 45                                2012ApJ...749L..28V
# 46                                2014A&A...562A..17E
# 47                                2013ApJ...767...71M
# 48  2013MNRAS.431..308K,2015MNRAS.454...95M,2019MN...
# 49                                2014MNRAS.439.1807B
# 50            2012ApJ...760...93H,2012ApJ...751...92R
# 51                                2013MNRAS.434.1636T
# 52            2015ApJ...799...51M,2019MNRAS.482.1545S
# 53            2013ApJ...770L..38M,2019MNRAS.482.1545S
# 54  2013ApJ...764L..13B,2013MNRAS.433.1871B,2014Ap...
# 55            2015MNRAS.450.2373B,2017MNRAS.467..369S
# 56            2014ApJ...797....5Z,2016ApJ...818....3K
# 57  2015MNRAS.448.2608V,2016PASA...33...55C,2017Ap...
# 58  2019MNRAS.482.1545S,2012MNRAS.425.1789S,2012PA...
# 59  2014MNRAS.438L.101V,2015ApJ...806..160B,2016Ap...
# 60            2016PASA...33...55C,2017NatPh..13..510Y
# 61                                2016ApJ...821...57D
# 62            2016MNRAS.462..137T,2012PASP..124..668Y
# 63                                2018MNRAS.475.3959H
# 64                                2018ApJ...861...63H
# 65                                2017ApJ...836L..12T
# 66  2013ApJ...775L...7C,2014A&A...565A.114F,2014MN...
#
#                       Ref Host  \
# 0   citet{2018arXiv181111771M}
# 1   citet{2019arXiv190109962A}
# 2   citet{1990PASP..102..131W}
# 3   citet{1994AJ....107.1022R}
# 4   citet{1996AJ....111..327R}
# 5   citet{2001ApJ...555..900P}
# 6   citet{2011MNRAS.411.2726B}
# 7   citet{2009AJ....137...34K}
# 8   citet{2003MNRAS.340..375P}
# 9   citet{2006MNRAS.371.1459T}
# 10  citet{2004IAUC.8413....1Z}
# 11  citet{2018A&A...609A.135S}
# 12  citet{2018A&A...609A.135S}
# 13  citet{2018A&A...609A.135S}
# 14  citet{2018A&A...609A.135S}
# 15  citet{2006ApJ...641.1039F}
# 16  citet{2007ApJ...662.1148B}
# 17                    citet{-}
# 18  citet{2018A&A...609A.135S}
# 19                    citet{-}
# 20  citet{2014ApJ...787..157P}
# 21  citet{2018A&A...609A.135S}
# 22  citet{2009ApJ...696..713S}
# 23  citet{2009A&A...508..371H}
# 24  citet{2011MNRAS.417..261I}
# 25  citet{2014ApJ...787..157P}
# 26  citet{2009ApJ...697..676S}
# 27  citet{2013MNRAS.434.2032R}
# 28  citet{2014ApJ...787..157P}
# 29  citet{2018A&A...609A.135S}
# ..                         ...
# 37  citet{2012MNRAS.422.1122I}
# 38  citet{2013A&A...555A.142I}
# 39  citet{2015MNRAS.450.3137T}
# 40  citet{2014ApJ...787..157P}
# 41                    citet{-}
# 42  citet{2014ApJ...787..157P}
# 43  citet{2010ApJ...714L.254E}
# 44  citet{2015MNRAS.449.1921P}
# 45  citet{2012ApJ...749L..28V}
# 46  citet{2013MNRAS.433....2S}
# 47  citet{2013ApJ...767...71M}
# 48  citet{2013MNRAS.431..308K}
# 49  citet{2014MNRAS.439.1807B}
# 50  citet{2013MNRAS.431.2599M}
# 51  citet{2013MNRAS.434.1636T}
# 52  citet{2015ApJ...799...51M}
# 53  citet{2013ApJ...772L..17T}
# 54  citet{2014ApJ...787..139D}
# 55  citet{2015MNRAS.450.2373B}
# 56  citet{2014ApJ...797....5Z}
# 57  citet{2015MNRAS.448.2608V}
# 58  citet{2014MNRAS.445.1647M}
# 59  citet{2014JAVSO..42..333R}
# 60  citet{2017NatPh..13..510Y}
# 61  citet{2016ApJ...821...57D}
# 62  citet{2016MNRAS.462..137T}
# 63  citet{2018MNRAS.475.3959H}
# 64  citet{2018ApJ...861...63H}
# 65  citet{2017ApJ...837L...2A}
# 66  citet{2016A&A...593A..68F}
#
#                                                 Notes  SIMS
# 0                                                 NaN  True
# 1                                      Fast Declining  True
# 2                                                 NaN  True
# 3               Strong CSM interactionn at late times  True
# 4                                                 NaN  True
# 5                                                 NaN  True
# 6                                                 NaN  True
# 7                                                 NaN  True
# 8                                                 NaN  True
# 9   Slow decline. Spectroscopically between Ic and...  True
# 10                                                NaN  True
# 11                                                NaN  True
# 12                                                NaN  True
# 13                                                NaN  True
# 14                                                NaN  True
# 15                                                NaN  True
# 16                Low-velocity ejecta and subluminous  True
# 17                                                NaN  True
# 18                                                NaN  True
# 19                            Peculiar at late phases  True
# 20                                      Fast Evolving  True
# 21                                                NaN  True
# 22                                                NaN  True
# 23                                                NaN  True
# 24                                     Fast Declining  True
# 25                                                NaN  True
# 26                                                NaN  True
# 27                                                NaN  True
# 28                                                NaN  True
# 29                                                NaN  True
# ..                                                ...   ...
# 37                                                NaN  True
# 38                                                NaN  True
# 39                             Unusually long plateau  True
# 40                                   Multi-peaked IIn  True
# 41                                                NaN  True
# 42                                                NaN  True
# 43                                                NaN  True
# 44                      Type Ibn, He-rich CSM, weak H  True
# 45            Slow Evolving (Very Massive Progenitor)  True
# 46                                                NaN  True
# 47                                                NaN  True
# 48                                     Double peaked   True
# 49                                     Fast and Faint  True
# 50  Spectroscopically IIn but well defined plateau...  True
# 51                                                NaN  True
# 52                                                NaN  True
# 53                              Fast expanding ejecta  True
# 54                              Long-Lived UV plateau  True
# 55                                                NaN  True
# 56                                Low-velocity ejecta  True
# 57                                     Fast Declining  True
# 58                                     Double peaked   True
# 59                                     Fast Declining  True
# 60            Interacting with circumstellar material  True
# 61                          Double-peaked. Type Ib/c   True
# 62                                     Fast Declining  True
# 63                                                NaN  True
# 64                                                NaN  True
# 65                                                NaN  True
# 66                                                NaN  True
#
# [67 rows x 21 columns]

# %%
class SNPhotometryClass():
    """Class with photometry for each object:
            - load the photometry from the DATA folder
            - get the phootmetry in each filter
            - plot the raw photometry 
            - fit the photometry using GP
    """
    
    def __init__(self, main_path, lc_path, snname, verbose=False):
        """
        """

        ## Initialise the class variables
        self.main_path = main_path
        self.lc_data_path = lc_path+'/'
        #self.lc_data_path = '/Users/mariavincenzi/PhD/pycoco_2/data/lc/'

        self.spec_data_path = main_path+'/spec/'
        self.snname = snname   
        self.set_data_directory(verbose)

    def set_data_directory(self, verbose):
        """
        Set a new data directory path.
        Enables the data directory to be changed by the user.
        """
        SNphotometry_PATH = os.path.join(self.lc_data_path, '%s.dat'%self.snname)
        
        try:
            if verbose: print('Looking for Photometry for %s in%s'%(self.snname, SNphotometry_PATH))
            if os.path.isfile(SNphotometry_PATH):
                if verbose: print ('Got it!')
                self.sn_rawphot_file = SNphotometry_PATH
                pass
            else:
                if not os.path.isdir(self.lc_data_path):
                    print ('I cant find the directory with photometry. Check %s'%self.lc_data_path)
                    pass
                else: 
                    print ('I cant find the file with photometry. Check %s'%SNphotometry_PATH)
                    pass
    
        except Exception as e:
            print (e)

    def load(self, verbose = False):
        """
        Loads a single photometry file.
        with ('MJD', 'flux', 'flux_err', 'filter')
        
        Parameters
        - verbose
        ----------
        Returns
        - photometry in all filters
        -------
        """
        if verbose: print('Loading %s'%self.sn_rawphot_file)
        try:
            lc_file = np.genfromtxt(self.sn_rawphot_file,
                                    names=['MJD','filter','flux','flux_err','FilterSet','Source'], 
                                    usecols=[0,1,2,3,4,5], 
                                    dtype=None,encoding="utf-8")

            mask_filt = np.array([f not in exclude_filt for f in lc_file['filter']])
            lc_no_badfilters = lc_file[mask_filt]
            mask_filt = np.array([~np.isnan(f) for f in lc_no_badfilters['flux']])
            self.phot = lc_no_badfilters[mask_filt]
            self.avail_filters = np.unique(self.phot['filter'])
            if verbose: print ('Photometry loaded')

        except Exception as e:
            print (e)
            print ('Are you sure you gave me the right format? Check documentation in case.')

    def get_availfilter(self, verbose = False):
        """
        get available filter for this SN
        """
        #if photometry is not already loaded, load it!
        if (not hasattr(self, "phot"))|(not hasattr(self, "avail_filters")):
            self.load()
        return self.avail_filters
        
    def get_singlefilter(self, single_filter, verbose = False):
        """
        Loads from photometry file just 1 filter photometry.
        with ('MJD', 'flux', 'flux_err', 'filter')
        
        Parameters
        - verbose
        ----------
        Returns
        - photometry in all filters
        -------
        """
        #if photometry is not already loaded, load it!
        if not hasattr(self, "phot"):
            self.load()

        if not (isinstance(single_filter, str)):
            print ('Single filter string please')
            return None
        
        if single_filter not in self.avail_filters:
            if verbose: print ('Looks like the filter you are looking for is not available')
            return None
        
        filt_index = self.phot['filter']==single_filter
        return self.phot[filt_index]
        
    def corr_dust_singlefilter(self, filter_name):
        if not hasattr(self, "corr_factors"):
            self.corr_factors = {}
        corr_factors_dict = self.corr_factors            

        self.get_dust()
        self.get_redshift()
        RV = RV_dict[self.SNType]
        print (RV)

        if 'swift' in filter_name:
            w,t = w,t=wtf.loadFilter(FILTER_PATH+'/Swift/%s.dat'%filter_name)
        elif self.snname in CSP_SNe:
            w,t = w,t=wtf.loadFilter(FILTER_PATH+'/Site3_CSP/%s.txt'%filter_name)
        else:
            w,t = w,t=wtf.loadFilter(FILTER_PATH+'/GeneralFilters/%s.dat'%filter_name)
            
        w_SNframe = w/(1.+self.redshift)
        
        if filter_name in Vega_filt: band = wtf.Band_Vega(w_SNframe,t)
        elif filter_name in AB_filt: band = wtf.Band_AB(w_SNframe,t)
        ext_corr_Host = (1./band.extinction(self.Hostebv, 'CCM', r_v = RV)).value
        print (filter_name, ext_corr_Host)

        if filter_name in Vega_filt: band = wtf.Band_Vega(w,t)
        elif filter_name in AB_filt: band = wtf.Band_AB(w,t)
        ext_corr_MW = (1./band.extinction(self.MWebv, 'CCM')).value

        corr_factors_dict[filter_name] = ext_corr_Host*ext_corr_MW
        self.corr_factors = corr_factors_dict           

    
    def get_dust(self):
        if self.snname not in info_objects.Name.values:
            raise Exception('This SN is not in the FINAL_INFO.dat file')
        else:
            info_singleobj = info_objects[info_objects.Name==self.snname]
            self.MWebv = info_singleobj['MW ebv'].values[0]
            Host_ebv = info_singleobj['Host ebv'].values[0]
            if 'ddag' in Host_ebv: 
                Host_ebv = float(Host_ebv.replace('ddag',''))
            self.Hostebv = Host_ebv
            self.SNType = (info_singleobj['Type'].values[0])
        
    def get_redshift(self):
        info_singleobj = info_objects[info_objects.Name==self.snname]
        self.redshift = info_singleobj['z'].values[0]

    def correct_final_LC(self, name_file = None):
        for ff in self.get_availfilter():
            self.corr_dust_singlefilter(ff)
        
        lc_file = pd.DataFrame(self.phot)
        corr_dust_array = [self.corr_factors[f] for f in lc_file['filter']]
        lc_file['flux_corr'] = corr_dust_array*lc_file['flux'].values
        lc_file['flux_corr_err'] = corr_dust_array*lc_file['flux_err'].values

        return lc_file

# %%
import sys
sys.path.insert(0, '/Users/mariavincenzi/PhD/Photometry_Utils/')

import what_the_flux as wtf

# %%
FILTER_PATH = "/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Sullivan_Filters/"

w,t=wtf.loadFilter(FILTER_PATH+'GeneralFilters/Bessell_B.dat')
band = wtf.Band_Vega(w,t)
ext_corr = 1./band.extinction(0.1, 'CCM')
print (ext_corr)
# Out:
# 1.4613061476437499

# %%
w_SNrestframe = w/(1.5)

band = wtf.Band_Vega(w_SNrestframe,t)
ext_corr = 1./band.extinction(0.1, 'CCM')
print (ext_corr)
# Out:
# 1.712531477835318

# %%
import shutil

RV_dict = {'Ic':4.3 , 'Ic-BL':4.3, 'Ib':2.6, 'IIb':1.1, 'II':3.1, 'IIn':3.1}

sn_list = [f.replace('.dat','') for f in os.listdir(DATALC_PATH) if '.dat' in f]

for sn in sn_list:
    try:
        prova2 = SNPhotometryClass(main_path=DATAMAIN_PATH, lc_path= DATALC_PATH,snname=sn, verbose=True)
        prova2.load()
        prova2.get_availfilter()
        df = prova2.correct_final_LC()
        df_to_print = df[['MJD', 'filter', 'flux_corr', 'flux_corr_err', 'FilterSet', 'Source']]
        df_to_print.to_csv(prova2.sn_rawphot_file.replace('/Final_LC_NOMW/','/Final_LC_NOMW_dust_corr_RV/'), na_rep='nan',
              index=False, sep='\t', header=['#MJD','band','Flux','Flux_err','FilterSet', 'Source'])
    except Exception as e:
        print (e, sn, 'NO CORRECTION')
# Out:
# Looking for Photometry for ASASSN14jb in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//ASASSN14jb.dat
# Got it!
# 3.1
# Bessell_B 1.0
# 3.1
# Bessell_V 1.0
# 3.1
# sdss_g 1.0
# 3.1
# sdss_i 1.0
# 3.1
# sdss_r 1.0
# 3.1
# swift_B 1.0
# 3.1
# swift_U 1.0
# 3.1
# swift_UVM2 1.0
# 3.1
# swift_UVW1 1.0
# 3.1
# swift_UVW2 1.0
# Looking for Photometry for ASASSN15no in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//ASASSN15no.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file ASASSN15no NO CORRECTION
# Looking for Photometry for ASASSN15oz in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//ASASSN15oz.dat
# Got it!
# 3.1
# Bessell_B 1.0
# 3.1
# Bessell_I 1.0
# 3.1
# Bessell_R 1.0
# 3.1
# Bessell_U 1.0
# 3.1
# Bessell_V 1.0
# 3.1
# sdss_g 1.0
# 3.1
# sdss_i 1.0
# 3.1
# sdss_r 1.0
# 3.1
# swift_B 1.0
# 3.1
# swift_U 1.0
# 3.1
# swift_UVM2 1.0
# 3.1
# swift_UVW1 1.0
# 3.1
# swift_UVW2 1.0
# 3.1
# swift_V 1.0
# Looking for Photometry for iPTF13bvn in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//iPTF13bvn.dat
# Got it!
# 2.6
# Bessell_B 1.7669864792771293
# 2.6
# Bessell_I 1.2592011377703283
# 2.6
# Bessell_R 1.3910331500320106
# 2.6
# Bessell_U 2.000786626460543
# 2.6
# Bessell_V 1.5119363833656827
# 2.6
# sdss_g' 1.6582384686682432
# 2.6
# sdss_i' 1.293016016665944
# 2.6
# sdss_r' 1.420110693578383
# 2.6
# sdss_z' 1.2029838275483826
# 2.6
# swift_B 1.7747137376259687
# 2.6
# swift_U 2.0461704223201673
# 2.6
# swift_UVW1 2.8500143777218416
# 2.6
# swift_UVW2 3.5860816111974425
# 2.6
# swift_V 1.5183798421006134
# Looking for Photometry for SN1987A in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN1987A.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN1987A NO CORRECTION
# Looking for Photometry for SN1993J in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN1993J.dat
# Got it!
# 1.1
# Bessell_B 1.2159396942864946
# 1.1
# Bessell_I 1.0275139515316432
# 1.1
# Bessell_R 1.069521337798358
# 1.1
# Bessell_U 1.320365115551195
# 1.1
# Bessell_V 1.1100114850793494
# Looking for Photometry for SN1994I in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN1994I.dat
# Got it!
# 4.3
# Bessell_B 7.778790645726687
# 4.3
# Bessell_I 2.9268511622224063
# 4.3
# Bessell_R 4.074736897551795
# 4.3
# Bessell_U 10.177145945665576
# 4.3
# Bessell_V 5.304621099338338
# Looking for Photometry for SN1996cb in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN1996cb.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN1996cb NO CORRECTION
# Looking for Photometry for SN1998A in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN1998A.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN1998A NO CORRECTION
# Looking for Photometry for SN1998bw in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN1998bw.dat
# Got it!
# 4.3
# Bessell_B 1.0
# 4.3
# Bessell_I 1.0
# 4.3
# Bessell_R 1.0
# 4.3
# Bessell_U 1.0
# 4.3
# Bessell_V 1.0
# Looking for Photometry for SN1998S in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN1998S.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN1998S NO CORRECTION
# Looking for Photometry for SN1999dn in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN1999dn.dat
# Got it!
# 2.6
# Bessell_B 1.1759292608103444
# 2.6
# Bessell_I 1.068011970455843
# 2.6
# Bessell_R 1.0985523005268718
# 2.6
# Bessell_U 1.2174137201631294
# 2.6
# Bessell_V 1.124798209649389
# Looking for Photometry for SN1999el in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN1999el.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN1999el NO CORRECTION
# Looking for Photometry for SN1999em in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN1999em.dat
# Got it!
# 3.1
# Bessell_B 1.3403860231043323
# 3.1
# Bessell_I 1.1406867789449955
# 3.1
# Bessell_R 1.1991883560119536
# 3.1
# Bessell_U 1.4143481211462765
# 3.1
# Bessell_V 1.2487732802264557
# Looking for Photometry for SN2000cb in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2000cb.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2000cb NO CORRECTION
# Looking for Photometry for SN2000eo in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2000eo.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2000eo NO CORRECTION
# Looking for Photometry for SN2002ap in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2002ap.dat
# Got it!
# 4.3
# Bessell_B 1.04005901707187
# 4.3
# Bessell_I 1.0207765297433675
# 4.3
# Bessell_R 1.027334199211555
# 4.3
# Bessell_U 1.0452203987859492
# 4.3
# Bessell_V 1.0324080515579996
# Looking for Photometry for SN2002gd in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2002gd.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2002gd NO CORRECTION
# Looking for Photometry for SN2003bg in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2003bg.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2003bg NO CORRECTION
# Looking for Photometry for SN2003jd in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2003jd.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2003jd NO CORRECTION
# Looking for Photometry for SN2004A in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2004A.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2004A NO CORRECTION
# Looking for Photometry for SN2004aw in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2004aw.dat
# Got it!
# 4.3
# Bessell_B 5.645509278851568
# 4.3
# Bessell_I 2.4976828378810896
# 4.3
# Bessell_R 3.287977402290709
# 4.3
# Bessell_U 6.984512475801274
# 4.3
# Bessell_V 4.095438590189643
# Looking for Photometry for SN2004dk in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2004dk.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2004dk NO CORRECTION
# Looking for Photometry for SN2004et in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2004et.dat
# Got it!
# 3.1
# Bessell_B 1.3046860397757443
# 3.1
# Bessell_I 1.1267969073101156
# 3.1
# Bessell_R 1.1792408213661938
# 3.1
# Bessell_U 1.3700981515736848
# 3.1
# Bessell_V 1.2234277080439266
# Looking for Photometry for SN2004fe in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2004fe.dat
# Got it!
# 4.3
# Bessell_B 1.0
# 4.3
# Bessell_V 1.0
# 4.3
# sdss_g 1.0
# 4.3
# sdss_i 1.0
# 4.3
# sdss_r 1.0
# 4.3
# sdss_u 1.0
# Looking for Photometry for SN2004gq in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2004gq.dat
# Got it!
# 2.6
# Bessell_B 1.2536703863639775
# 2.6
# Bessell_V 1.1824783307328035
# 2.6
# sdss_g 1.2234518921023
# 2.6
# sdss_i 1.1064930246476634
# 2.6
# sdss_r 1.148936104337244
# 2.6
# sdss_u 1.3138204479483169
# Looking for Photometry for SN2004gt in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2004gt.dat
# Got it!
# 4.3
# Bessell_B 3.2109362035007707
# 4.3
# Bessell_V 2.620117785099608
# 4.3
# sdss_g 2.9517190001193567
# 4.3
# sdss_i 1.9336580687490836
# 4.3
# sdss_r 2.3138838261842896
# 4.3
# sdss_u 3.7112322327260197
# Looking for Photometry for SN2004gv in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2004gv.dat
# Got it!
# 2.6
# Bessell_B 1.1994397363661173
# 2.6
# Bessell_V 1.144649624506403
# 2.6
# sdss_g 1.1765099272292399
# 2.6
# sdss_i 1.0856021282766795
# 2.6
# sdss_r 1.1182183233733811
# 2.6
# sdss_u 1.2438363896516862
# Looking for Photometry for SN2005bf in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2005bf.dat
# Got it!
# 2.6
# Bessell_B 1.4083553543167313
# 2.6
# Bessell_V 1.2897199994821007
# 2.6
# sdss_g 1.357794728028145
# 2.6
# sdss_i 1.1671889523686765
# 2.6
# sdss_r 1.2342536704552998
# 2.6
# sdss_u 1.5087331953349596
# Looking for Photometry for SN2005cp in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2005cp.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2005cp NO CORRECTION
# Looking for Photometry for SN2005cs in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2005cs.dat
# Got it!
# 3.1
# Bessell_B 1.0587307939370358
# 3.1
# Bessell_I 1.0259488045980536
# 3.1
# Bessell_R 1.0360156176847053
# 3.1
# Bessell_U 1.0698405171618282
# 3.1
# Bessell_V 1.0442044634281813
# 3.1
# sdss_z 1.0213652914758633
# 3.1
# swift_B 1.0590904943864115
# 3.1
# swift_UVM2 1.127576507828298
# 3.1
# swift_UVW1 1.1016110387679454
# 3.1
# swift_UVW2 1.121009423049057
# Looking for Photometry for SN2005db in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2005db.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2005db NO CORRECTION
# Looking for Photometry for SN2005hg in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2005hg.dat
# Got it!
# 2.6
# Bessell_B 2.1447595906099206
# 2.6
# Bessell_U 2.5195952884679915
# 2.6
# Bessell_V 1.742746564254926
# 2.6
# sdss_i' 1.416642226546237
# 2.6
# sdss_r' 1.6011425125306071
# Looking for Photometry for SN2006aa in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2006aa.dat
# Got it!
# 3.1
# Bessell_B 1.3704200076729045
# 3.1
# Bessell_V 1.2765220638126622
# 3.1
# sdss_g' 1.331017508169818
# 3.1
# sdss_i' 1.169402160174396
# 3.1
# sdss_r' 1.2291334792981454
# 3.1
# sdss_u' 1.4448586361367657
# Looking for Photometry for SN2006aj in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2006aj.dat
# Got it!
# 4.3
# Bessell_B 2.7289017849912414
# 4.3
# Bessell_U 3.0573357465845854
# 4.3
# Bessell_V 2.269438698012772
# 4.3
# sdss_i' 1.7866203689008386
# 4.3
# sdss_r' 2.068475434020779
# 4.3
# swift_B 2.743944700353632
# 4.3
# swift_U 3.100594451834939
# 4.3
# swift_UVM2 5.107858625722713
# 4.3
# swift_UVW1 4.06549335781122
# 4.3
# swift_UVW2 4.479628576561767
# 4.3
# swift_V 2.285762631432661
# Looking for Photometry for SN2006bp in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2006bp.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2006bp NO CORRECTION
# Looking for Photometry for SN2006el in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2006el.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2006el NO CORRECTION
# Looking for Photometry for SN2006ep in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2006ep.dat
# Got it!
# 2.6
# Bessell_B 2.2087598740011396
# 2.6
# Bessell_V 1.8022649074293031
# 2.6
# sdss_g 2.0266465637554
# 2.6
# sdss_i 1.429347743149657
# 2.6
# sdss_r 1.6283194067679114
# 2.6
# sdss_u 2.5983890015268787
# Looking for Photometry for SN2006jc in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2006jc.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2006jc NO CORRECTION
# Looking for Photometry for SN2006T in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2006T.dat
# Got it!
# 1.1
# Bessell_B 1.736409609992285
# 1.1
# Bessell_V 1.3630819026248087
# 1.1
# sdss_g 1.5620296186480127
# 1.1
# sdss_i 1.111973058657846
# 1.1
# sdss_r 1.2384234216982908
# 1.1
# sdss_u 2.1625611920241705
# Looking for Photometry for SN2006V in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2006V.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2006V NO CORRECTION
# Looking for Photometry for SN2007C in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2007C.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2007C NO CORRECTION
# Looking for Photometry for SN2007gr in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2007gr.dat
# Got it!
# 4.3
# Bessell_B 1.158579940979777
# 4.3
# Bessell_I 1.0800822937439791
# 4.3
# Bessell_R 1.1063167289131848
# 4.3
# Bessell_U 1.1803594647818805
# 4.3
# Bessell_V 1.1269654324719567
# 4.3
# sdss_i' 1.0870811537067986
# 4.3
# sdss_r' 1.1116574067994547
# Looking for Photometry for SN2007od in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2007od.dat
# Got it!
# 3.1
# Bessell_B 1.0
# 3.1
# Bessell_I 1.0
# 3.1
# Bessell_R 1.0
# 3.1
# Bessell_U 1.0
# 3.1
# Bessell_V 1.0
# 3.1
# sdss_i' 1.0
# 3.1
# sdss_r' 1.0
# 3.1
# swift_B 1.0
# 3.1
# swift_U 1.0
# 3.1
# swift_UVM2 1.0
# 3.1
# swift_UVW1 1.0
# 3.1
# swift_UVW2 1.0
# 3.1
# swift_V 1.0
# Looking for Photometry for SN2007pk in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2007pk.dat
# Got it!
# 3.1
# Bessell_B 1.3673721665195344
# 3.1
# Bessell_I 1.1526638644384979
# 3.1
# Bessell_R 1.2146810876728538
# 3.1
# Bessell_V 1.2682785646411154
# 3.1
# sdss_i' 1.1690387341493302
# 3.1
# sdss_r' 1.2277168765630733
# 3.1
# swift_B 1.370136129924754
# 3.1
# swift_U 1.4589946422036242
# 3.1
# swift_UVM2 1.9198900109123194
# 3.1
# swift_UVW1 1.6972805077594366
# 3.1
# swift_UVW2 1.8452810131968105
# 3.1
# swift_V 1.2710775669573346
# Looking for Photometry for SN2007ru in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2007ru.dat
# Got it!
# 4.3
# Bessell_B 1.0
# 4.3
# Bessell_I 1.0
# 4.3
# Bessell_R 1.0
# 4.3
# Bessell_U 1.0
# 4.3
# Bessell_V 1.0
# Looking for Photometry for SN2007uy in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2007uy.dat
# Got it!
# 2.6
# Bessell_B 8.152881332893287
# 2.6
# Bessell_V 4.623498587927667
# 2.6
# sdss_i' 2.5925121111208607
# 2.6
# sdss_r' 3.668970040985419
# 2.6
# swift_B 8.335033447659203
# 2.6
# swift_U 14.147070121331629
# 2.6
# swift_UVM2 122.77534886476842
# 2.6
# swift_UVW1 38.99721253180753
# 2.6
# swift_UVW2 92.33752084922074
# 2.6
# swift_V 4.712265192417397
# Looking for Photometry for SN2007Y in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2007Y.dat
# Got it!
# 2.6
# Bessell_B 1.3537226721674982
# 2.6
# Bessell_V 1.251741146151693
# 2.6
# sdss_g 1.310020854119702
# 2.6
# sdss_i 1.1450154802100356
# 2.6
# sdss_r 1.204446971827345
# 2.6
# sdss_u 1.4420697459162566
# 2.6
# swift_B 1.355321035837006
# 2.6
# swift_U 1.4613051310170104
# 2.6
# swift_UVM2 2.0419091695344553
# 2.6
# swift_UVW1 1.75211583260313
# 2.6
# swift_UVW2 1.9744437809772204
# 2.6
# swift_V 1.2475827321433284
# Looking for Photometry for SN2008aq in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2008aq.dat
# Got it!
# 1.1
# Bessell_B 1.0
# 1.1
# Bessell_V 1.0
# 1.1
# sdss_g 1.0
# 1.1
# sdss_i 1.0
# 1.1
# sdss_r 1.0
# 1.1
# sdss_u 1.0
# 1.1
# swift_B 1.0
# 1.1
# swift_U 1.0
# 1.1
# swift_UVW1 1.0
# 1.1
# swift_UVW2 1.0
# 1.1
# swift_V 1.0
# Looking for Photometry for SN2008ax in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2008ax.dat
# Got it!
# 1.1
# Bessell_B 1.7272894473148415
# 1.1
# Bessell_I 1.0797193539223213
# 1.1
# Bessell_R 1.2074511378859736
# 1.1
# Bessell_U 2.1786783691029803
# 1.1
# Bessell_V 1.3405685443998876
# 1.1
# sdss_g' 1.5499098619765082
# 1.1
# sdss_i' 1.1112843485553778
# 1.1
# sdss_r' 1.2366334116381887
# 1.1
# sdss_u' 2.20447336052553
# 1.1
# sdss_z' 1.037887440521583
# 1.1
# swift_B 1.74073552261112
# 1.1
# swift_U 2.291489157313308
# 1.1
# swift_UVW1 4.492913510827485
# 1.1
# swift_UVW2 7.733991217206452
# 1.1
# swift_V 1.3470011658942043
# Looking for Photometry for SN2008bj in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2008bj.dat
# Got it!
# 3.1
# Bessell_B 1.3684175326221166
# 3.1
# Bessell_U 1.4458507199450938
# 3.1
# Bessell_V 1.2691148187648245
# 3.1
# sdss_i' 1.169742065376443
# 3.1
# sdss_r' 1.2283916112815085
# Looking for Photometry for SN2008bo in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2008bo.dat
# Got it!
# 1.1
# Bessell_B 1.0676026193829566
# 1.1
# Bessell_V 1.0355783266077514
# 1.1
# sdss_i' 1.012776212957562
# 1.1
# sdss_r' 1.0256068792184931
# 1.1
# swift_U 1.1039325239015776
# 1.1
# swift_UVW1 1.2084620074879555
# 1.1
# swift_UVW2 1.2830437266613854
# Looking for Photometry for SN2008D in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2008D.dat
# Got it!
# 2.6
# Bessell_B 7.385990923020157
# 2.6
# Bessell_V 4.300000147191519
# 2.6
# sdss_i' 2.4781947169735594
# 2.6
# sdss_r' 3.4496131046702594
# 2.6
# swift_B 7.54019506729972
# 2.6
# swift_U 12.47764209052436
# 2.6
# swift_UVW1 33.19752055464304
# 2.6
# swift_V 4.3777118136663615
# Looking for Photometry for SN2008fq in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2008fq.dat
# Got it!
# 3.1
# Bessell_B 5.821610998348843
# 3.1
# Bessell_V 3.921122298083522
# 3.1
# sdss_g' 4.9089796934580985
# 3.1
# sdss_i' 2.3901276860869816
# 3.1
# sdss_r' 3.174996661721436
# 3.1
# sdss_u' 7.965668790804647
# Looking for Photometry for SN2008in in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2008in.dat
# Got it!
# 3.1
# Bessell_B 1.33649531867099
# 3.1
# Bessell_V 1.246091960542666
# 3.1
# sdss_i' 1.1546309603606717
# 3.1
# sdss_r' 1.2092259174803384
# 3.1
# swift_B 1.3389346282140184
# 3.1
# swift_U 1.4212202561439164
# 3.1
# swift_UVM2 1.8364231864231033
# 3.1
# swift_UVW1 1.631057943133495
# 3.1
# swift_UVW2 1.7791623729910149
# 3.1
# swift_V 1.248631637221537
# Looking for Photometry for SN2009bb in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2009bb.dat
# Got it!
# 4.3
# Bessell_B 14.293613285588398
# 4.3
# Bessell_V 9.026442320106955
# 4.3
# sdss_g 11.75027224830886
# 4.3
# sdss_i 4.519890357963178
# 4.3
# sdss_r 6.794158542643114
# 4.3
# sdss_u 19.92333738699775
# Looking for Photometry for SN2009bw in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2009bw.dat
# Got it!
# 3.1
# Bessell_B 1.3563991160577396
# 3.1
# Bessell_I 1.1469573729744116
# 3.1
# Bessell_R 1.2081052217846335
# 3.1
# Bessell_U 1.4340629240258755
# 3.1
# Bessell_V 1.2601139531717378
# 3.1
# swift_UVM2 1.8946171788821802
# 3.1
# swift_UVW2 1.833910248218863
# Looking for Photometry for SN2009dd in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2009dd.dat
# Got it!
# 3.1
# Bessell_B 5.1466994411818785
# 3.1
# Bessell_I 2.0912281180644006
# 3.1
# Bessell_R 2.7611862803417817
# 3.1
# Bessell_U 7.008604118446923
# 3.1
# Bessell_V 3.47629947186819
# 3.1
# sdss_i' 2.2536585204783104
# 3.1
# sdss_r' 2.9337779769762307
# Looking for Photometry for SN2009E in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2009E.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2009E NO CORRECTION
# Looking for Photometry for SN2009er in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2009er.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2009er NO CORRECTION
# Looking for Photometry for SN2009ib in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2009ib.dat
# Got it!
# 3.1
# Bessell_B 1.6471755577194767
# 3.1
# Bessell_I 1.251856832774096
# 3.1
# Bessell_R 1.3627843526358552
# 3.1
# Bessell_V 1.4603576167536885
# 3.1
# sdss_g' 1.569491400271903
# 3.1
# sdss_i' 1.280611598687599
# 3.1
# sdss_r' 1.3868181475248973
# 3.1
# sdss_u' 1.8120503832130155
# 3.1
# sdss_z' 1.2019681251395957
# Looking for Photometry for SN2009ip in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2009ip.dat
# Got it!
# 3.1
# Bessell_B 1.0389728893398182
# 3.1
# Bessell_I 1.0173661452843907
# 3.1
# Bessell_R 1.0240042364812156
# 3.1
# Bessell_V 1.0294126466414448
# 3.1
# swift_U 1.0473809719468608
# 3.1
# swift_UVM2 1.0836269542704415
# 3.1
# swift_UVW1 1.067083949037226
# 3.1
# swift_UVW2 1.079085354203874
# Looking for Photometry for SN2009iz in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2009iz.dat
# Got it!
# 2.6
# Bessell_B 2.131411063581965
# 2.6
# Bessell_V 1.7339354241196665
# 2.6
# sdss_i' 1.4104926245449347
# 2.6
# sdss_r' 1.5947234439420583
# 2.6
# sdss_u' 2.5255984955253963
# 2.6
# swift_UVW1 4.000289825698904
# Looking for Photometry for SN2009jf in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2009jf.dat
# Got it!
# 2.6
# Bessell_B 1.106449354238262
# 2.6
# Bessell_I 1.0418756602509813
# 2.6
# Bessell_R 1.0604117205367867
# 2.6
# Bessell_U 1.1306971418023928
# 2.6
# Bessell_V 1.0761441266217713
# 2.6
# sdss_g 1.0958715079412331
# 2.6
# sdss_i 1.0480130563319408
# 2.6
# sdss_i' 1.046776872897493
# 2.6
# sdss_r 1.0648334840475682
# 2.6
# sdss_r' 1.0642110008839016
# 2.6
# sdss_u 1.1306024148277791
# 2.6
# sdss_u' 1.1318157565373297
# 2.6
# sdss_z 1.0336996151747622
# Looking for Photometry for SN2009kr in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2009kr.dat
# Got it!
# 3.1
# Bessell_B 1.0
# 3.1
# Bessell_I 1.0
# 3.1
# Bessell_R 1.0
# 3.1
# Bessell_V 1.0
# 3.1
# swift_B 1.0
# 3.1
# swift_U 1.0
# 3.1
# swift_UVM2 1.0
# 3.1
# swift_UVW1 1.0
# 3.1
# swift_UVW2 1.0
# 3.1
# swift_V 1.0
# Looking for Photometry for SN2009mg in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2009mg.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2009mg NO CORRECTION
# Looking for Photometry for SN2009N in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2009N.dat
# Got it!
# 3.1
# Bessell_B 1.5375422567315493
# 3.1
# Bessell_I 1.2134638634090327
# 3.1
# Bessell_R 1.3057444814988888
# 3.1
# Bessell_V 1.3858967992334317
# 3.1
# sdss_g' 1.474832384493518
# 3.1
# sdss_i' 1.2374620082430143
# 3.1
# sdss_r' 1.3255365103095107
# 3.1
# sdss_z' 1.1716844630673162
# 3.1
# swift_B 1.5418073022327172
# 3.1
# swift_U 1.6851897475018773
# 3.1
# swift_UVM2 2.4610925599308606
# 3.1
# swift_UVW1 2.0598498755364636
# 3.1
# swift_UVW2 2.3509337676421427
# 3.1
# swift_V 1.3901606022646416
# Looking for Photometry for SN2010al in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2010al.dat
# Got it!
# 3.1
# Bessell_B 1.2273900765539194
# 3.1
# Bessell_I 1.097512582020428
# 3.1
# Bessell_R 1.1358290280070629
# 3.1
# Bessell_V 1.1683648973003136
# 3.1
# sdss_i' 1.1076916138282007
# 3.1
# sdss_r' 1.1437553960317584
# 3.1
# sdss_u' 1.2744994191151817
# 3.1
# swift_B 1.2289820912095812
# 3.1
# swift_U 1.2805273000493573
# 3.1
# swift_UVM2 1.5333781879256607
# 3.1
# swift_UVW1 1.4154445213725246
# 3.1
# swift_UVW2 1.4940660893935587
# 3.1
# swift_V 1.17003058792955
# Looking for Photometry for SN2010bq in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2010bq.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2010bq NO CORRECTION
# Looking for Photometry for SN2011bm in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2011bm.dat
# Got it!
# 4.3
# Bessell_B 1.1700758926045522
# 4.3
# Bessell_I 1.0857104340247015
# 4.3
# Bessell_R 1.1138542256347452
# 4.3
# Bessell_U 1.1935185757854507
# 4.3
# Bessell_V 1.1360474005374466
# 4.3
# sdss_g' 1.156783941579808
# 4.3
# sdss_i' 1.0932165171400392
# 4.3
# sdss_r' 1.1195912902888332
# 4.3
# sdss_u' 1.194450995501786
# 4.3
# sdss_z' 1.0715451792239243
# Looking for Photometry for SN2011dh in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2011dh.dat
# Got it!
# 1.1
# Bessell_B 1.1032738063128305
# 1.1
# Bessell_I 1.013819779070497
# 1.1
# Bessell_R 1.0343725602643696
# 1.1
# Bessell_U 1.1495957124241671
# 1.1
# Bessell_V 1.0538509178232014
# 1.1
# sdss_g' 1.0822715829818992
# 1.1
# sdss_i' 1.0190624085591857
# Looking for Photometry for SN2011ei in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2011ei.dat
# Got it!
# 1.1
# Bessell_B 1.4311327051636134
# 1.1
# Bessell_I 1.0531340500182733
# 1.1
# Bessell_R 1.132007949060899
# 1.1
# Bessell_V 1.2123251025280835
# 1.1
# swift_B 1.4379933232575839
# 1.1
# swift_U 1.7187362846994017
# 1.1
# swift_UVW1 2.731493649029975
# 1.1
# swift_UVW2 3.807268823756086
# 1.1
# swift_V 1.2160098660091248
# Looking for Photometry for SN2011fe in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2011fe.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2011fe NO CORRECTION
# Looking for Photometry for SN2011fu in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2011fu.dat
# Got it!
# 1.1
# Bessell_B 1.031108645373151
# 1.1
# Bessell_I 1.0045896774645926
# 1.1
# Bessell_R 1.0106893156356294
# 1.1
# Bessell_U 1.0439794597054164
# 1.1
# Bessell_V 1.01663386439528
# 1.1
# sdss_u 1.0438001521591391
# 1.1
# sdss_z 1.0022820544191788
# Looking for Photometry for SN2011hs in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2011hs.dat
# Got it!
# 1.1
# Bessell_B 1.3720665064844855
# 1.1
# Bessell_I 1.0460403943064949
# 1.1
# Bessell_R 1.1153503975167267
# 1.1
# Bessell_U 1.5659008228933067
# 1.1
# Bessell_V 1.1847395527968878
# 1.1
# sdss_g' 1.2897415466347746
# 1.1
# sdss_i' 1.0635740966178469
# 1.1
# sdss_r' 1.1305034956063653
# 1.1
# sdss_u' 1.5763992655724268
# 1.1
# sdss_z' 1.0219524342205146
# 1.1
# swift_B 1.3777319161194799
# 1.1
# swift_U 1.6136605944427227
# 1.1
# swift_UVW1 2.437644798738966
# 1.1
# swift_UVW2 3.2890053506170918
# 1.1
# swift_V 1.1878630022952357
# Looking for Photometry for SN2011ht in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2011ht.dat
# Got it!
# 3.1
# Bessell_B 1.2616841251298334
# 3.1
# Bessell_I 1.1101839442807155
# 3.1
# Bessell_R 1.1550649591821163
# 3.1
# Bessell_V 1.1927619978582404
# 3.1
# swift_B 1.2635021271665587
# 3.1
# swift_U 1.3255534015582768
# 3.1
# swift_UVM2 1.6285858241625508
# 3.1
# swift_UVW1 1.4806970813393516
# 3.1
# swift_UVW2 1.5888375601052194
# 3.1
# swift_V 1.1946966766432394
# Looking for Photometry for SN2012A in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2012A.dat
# Got it!
# 3.1
# Bessell_B 1.0467574502489363
# 3.1
# Bessell_I 1.0207358399483353
# 3.1
# Bessell_R 1.0287398500015812
# 3.1
# Bessell_U 1.0555223235143114
# 3.1
# Bessell_V 1.0352434042314291
# Looking for Photometry for SN2012ap in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2012ap.dat
# Got it!
# 4.3
# Bessell_B 7.17846076958017
# 4.3
# Bessell_I 2.8282494016042397
# 4.3
# Bessell_R 3.871788161409262
# 4.3
# Bessell_V 4.978226523717097
# 4.3
# swift_B 7.265262204132663
# 4.3
# swift_U 9.446065396997822
# 4.3
# swift_UVW1 15.096817220606244
# 4.3
# swift_V 5.055589046672112
# Looking for Photometry for SN2012au in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2012au.dat
# Got it!
# 2.6
# Bessell_B 1.0
# 2.6
# Bessell_I 1.0
# 2.6
# Bessell_R 1.0
# 2.6
# Bessell_V 1.0
# 2.6
# sdss_z 1.0
# 2.6
# swift_B 1.0
# 2.6
# swift_U 1.0
# 2.6
# swift_UVM2 1.0
# 2.6
# swift_UVW1 1.0
# 2.6
# swift_UVW2 1.0
# 2.6
# swift_V 1.0
# Looking for Photometry for SN2012aw in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2012aw.dat
# Got it!
# 3.1
# Bessell_B 1.1125276902385595
# 3.1
# Bessell_I 1.0490728636096094
# 3.1
# Bessell_R 1.0683565427637767
# 3.1
# Bessell_U 1.1343961471340769
# 3.1
# Bessell_V 1.0841935978342196
# 3.1
# sdss_g 1.1027258825664081
# 3.1
# sdss_i 1.055460919298556
# 3.1
# sdss_r 1.0729505234247485
# 3.1
# sdss_u 1.1343996767625584
# 3.1
# sdss_z 1.0403250605901089
# 3.1
# swift_B 1.1132428950542932
# 3.1
# swift_U 1.1380241890908251
# 3.1
# swift_UVM2 1.2512394687149426
# 3.1
# swift_UVW1 1.197963532197499
# 3.1
# swift_UVW2 1.2373989171544568
# 3.1
# swift_V 1.0849878425741972
# Looking for Photometry for SN2012ec in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2012ec.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2012ec NO CORRECTION
# Looking for Photometry for SN2013ab in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2013ab.dat
# Got it!
# 3.1
# Bessell_B 1.0793969044078813
# 3.1
# Bessell_I 1.0349902490611123
# 3.1
# Bessell_R 1.0485383463711924
# 3.1
# Bessell_V 1.0596406544018948
# 3.1
# sdss_g 1.0726007689278283
# 3.1
# sdss_i 1.039492802229797
# 3.1
# sdss_r 1.0517484593386877
# 3.1
# swift_B 1.0798939725422907
# 3.1
# swift_U 1.0969557158681298
# 3.1
# swift_UVM2 1.1740650357720428
# 3.1
# swift_UVW1 1.1383746038801705
# 3.1
# swift_UVW2 1.1643362741038112
# Looking for Photometry for SN2013am in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2013am.dat
# Got it!
# 3.1
# Bessell_B 7.985831296602429
# 3.1
# Bessell_I 2.550857034605121
# 3.1
# Bessell_R 3.625393597690552
# 3.1
# Bessell_U 11.853874978542358
# 3.1
# Bessell_V 4.862829692159439
# 3.1
# sdss_i 2.8762403915942563
# 3.1
# swift_B 8.131135266588194
# 3.1
# swift_U 12.591392930034552
# 3.1
# swift_UVM2 70.64229301080907
# 3.1
# swift_UVW1 28.53807790995908
# 3.1
# swift_UVW2 55.97824950120886
# Looking for Photometry for SN2013by in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2013by.dat
# Got it!
# 3.1
# Bessell_B 1.0
# 3.1
# Bessell_V 1.0
# 3.1
# sdss_g 1.0
# 3.1
# sdss_i 1.0
# 3.1
# sdss_r 1.0
# 3.1
# sdss_u 1.0
# 3.1
# swift_U 1.0
# 3.1
# swift_UVM2 1.0
# 3.1
# swift_UVW1 1.0
# 3.1
# swift_UVW2 1.0
# 3.1
# swift_V 1.0
# Looking for Photometry for SN2013df in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2013df.dat
# Got it!
# 1.1
# Bessell_B 1.170473369648164
# 1.1
# Bessell_I 1.0223176165998091
# 1.1
# Bessell_R 1.055666671099713
# 1.1
# Bessell_U 1.2501753718804052
# 1.1
# Bessell_V 1.0877276770104567
# 1.1
# swift_B 1.1727053446090603
# 1.1
# swift_U 1.2690515924878425
# 1.1
# swift_UVM2 1.8587918024763241
# 1.1
# swift_UVW1 1.5703536824993802
# 1.1
# swift_UVW2 1.8236629955607921
# 1.1
# swift_V 1.0890902489092213
# Looking for Photometry for SN2013ej in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2013ej.dat
# Got it!
# 3.1
# Bessell_B 1.2049848181399576
# 3.1
# Bessell_I 1.0873646091991904
# 3.1
# Bessell_R 1.1225630135554248
# 3.1
# Bessell_U 1.246824402752422
# 3.1
# Bessell_V 1.151853705598641
# 3.1
# sdss_g 1.1864572563623041
# 3.1
# sdss_i 1.098979173956948
# 3.1
# sdss_r 1.1310543386570204
# 3.1
# sdss_z 1.0715687393191422
# 3.1
# swift_B 1.2063605207697141
# 3.1
# swift_U 1.2537907984187568
# 3.1
# swift_UVM2 1.4794039996927755
# 3.1
# swift_UVW1 1.3704640904052185
# 3.1
# swift_UVW2 1.4510642456584364
# 3.1
# swift_V 1.1533442808549927
# Looking for Photometry for SN2013fs in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2013fs.dat
# Got it!
# 3.1
# Bessell_B 1.0594054200007972
# 3.1
# Bessell_I 1.0264454860930556
# 3.1
# Bessell_R 1.0364901051793332
# 3.1
# Bessell_V 1.0447582883131434
# 3.1
# sdss_r 1.038860045206503
# 3.1
# swift_U 1.0722252318814027
# 3.1
# swift_UVM2 1.1284854297041444
# 3.1
# swift_UVW1 1.1030739269341443
# 3.1
# swift_UVW2 1.1207565681522973
# Looking for Photometry for SN2013ge in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2013ge.dat
# Got it!
# 4.3
# Bessell_I 1.129048468793448
# 4.3
# Bessell_R 1.1722091077717014
# 4.3
# Bessell_V 1.2067194117678615
# 4.3
# sdss_i' 1.1405319081966268
# 4.3
# sdss_r' 1.1810969599381953
# 4.3
# swift_B 1.2615964248533142
# 4.3
# swift_U 1.3013021443990216
# 4.3
# swift_UVM2 1.465750664609317
# 4.3
# swift_UVW1 1.3829629024214378
# 4.3
# swift_UVW2 1.4308168614681047
# 4.3
# swift_V 1.208592281337084
# Looking for Photometry for SN2013hj in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2013hj.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2013hj NO CORRECTION
# Looking for Photometry for SN2014G in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2014G.dat
# Got it!
# 3.1
# Bessell_B 2.4943941025851113
# 3.1
# Bessell_I 1.5099190779152574
# 3.1
# Bessell_R 1.762970678094644
# 3.1
# Bessell_U 2.9512127932833336
# 3.1
# Bessell_V 2.0021606395215628
# 3.1
# swift_UVM2 6.695113694310754
# 3.1
# swift_UVW1 4.559741933103675
# 3.1
# swift_UVW2 6.04603516229569
# 3.1
# swift_V 2.0160369963148064
# Looking for Photometry for SN2016bkv in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2016bkv.dat
# Got it!
# 3.1
# Bessell_B 1.0
# 3.1
# Bessell_I 1.0
# 3.1
# Bessell_R 1.0
# 3.1
# Bessell_U 1.0
# 3.1
# Bessell_V 1.0
# 3.1
# sdss_g 1.0
# 3.1
# sdss_i 1.0
# 3.1
# sdss_r 1.0
# Looking for Photometry for SN2016gkg in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2016gkg.dat
# Got it!
# 1.1
# Bessell_B 1.1948663742291326
# 1.1
# Bessell_I 1.0255497132682234
# 1.1
# Bessell_R 1.0632868733948337
# 1.1
# Bessell_V 1.0999300666351706
# 1.1
# sdss_g 1.1594814573985057
# 1.1
# sdss_r 1.0725937684295754
# 1.1
# swift_B 1.1974820207373291
# 1.1
# swift_U 1.3089708400453999
# 1.1
# swift_UVM2 2.011410671660512
# 1.1
# swift_UVW1 1.6637941961847356
# 1.1
# swift_UVW2 1.9648285277999566
# 1.1
# swift_V 1.101502692590506
# Looking for Photometry for SN2016X in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2016X.dat
# Got it!
# 3.1
# Bessell_B 1.079315623106907
# 3.1
# Bessell_I 1.034931303420511
# 3.1
# Bessell_R 1.0484817414989447
# 3.1
# Bessell_U 1.0943735735270792
# 3.1
# Bessell_V 1.0595746689863386
# 3.1
# sdss_g 1.0725185550496377
# 3.1
# sdss_i 1.0394319105178413
# 3.1
# sdss_r 1.0516931143229775
# 3.1
# swift_B 1.0798111671555533
# 3.1
# swift_U 1.0968887487336794
# 3.1
# swift_UVM2 1.1739486770935526
# 3.1
# swift_UVW1 1.138197428249974
# 3.1
# swift_UVW2 1.164366510642148
# 3.1
# swift_V 1.0601279355692463
# Looking for Photometry for SN2017eaw in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2017eaw.dat
# Got it!
# This SN is not in the FINAL_INFO.dat file SN2017eaw NO CORRECTION

# %%
RV_dict = {'Ic':3.1 , 'Ic-BL':3.1, 'Ib':3.1, 'IIb':3.1, 'II':3.1, 'IIn':3.1}

sn_list = [f.replace('.dat','') for f in os.listdir(DATALC_PATH) if '.dat' in f]
sn_list=['SN2005bf']
for sn in sn_list:
    try:
        prova2 = SNPhotometryClass(main_path=DATAMAIN_PATH, lc_path= DATALC_PATH,snname=sn, verbose=True)
        prova2.load()
        prova2.get_availfilter()
        df = prova2.correct_final_LC()
        df_to_print = df[['MJD', 'filter', 'flux_corr', 'flux_corr_err', 'FilterSet', 'Source']]
        df_to_print.to_csv(prova2.sn_rawphot_file.replace('/Final_LC_NOMW/','/Final_LC_NOMW_dust_corr/'), na_rep='nan',
              index=False, sep='\t', header=['#MJD','band','Flux','Flux_err','FilterSet', 'Source'])
    except Exception as e:
        print (e, sn, 'NO CORRECTION')
# Out:
# Looking for Photometry for SN2005bf in/Users/mariavincenzi/PhD/pycoco_2/prepare_photometry/Final_LC_NOMW//SN2005bf.dat
# Got it!
# 3.1
# Bessell_B 1.4743462349889707
# 3.1
# Bessell_V 1.3508307055247417
# 3.1
# sdss_g 1.4220928010342553
# 3.1
# sdss_i 1.2124005062257164
# 3.1
# sdss_r 1.2893679329967909
# 3.1
# sdss_u 1.5742951979387076
